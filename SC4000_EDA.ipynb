# %%
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
import pandas as pd

# %% [raw]
# # exploratory data analysis - cn0dbhz
#     # no outlier removal since most values are within valid cn0dbhz raange of 0 to 63 dBHz
#     # distribution is gaussian with slight negative skew
#     # slight negative correlation between cn0dbhz vs errorx or errory

# %%
# %store -r cn0dbhz_merge_df

f, axes = plt.subplots(1, 3, figsize=(40,20))

# uni-variate visualisation for cn0dbhz eda

cn0dbhz_eda_uni = pd.DataFrame(cn0dbhz_merge_df[["Cn0DbHz"]])
sb.boxplot(cn0dbhz_eda_uni, orient = "h", color = "g", ax = axes[0]) # boxplot for Cn0DbHz
sb.distplot(cn0dbhz_eda_uni, kde = True, color = "g", ax = axes[1]) # distplot for Cn0DbHz
sb.violinplot(cn0dbhz_eda_uni, orient = "h", color = "g", ax = axes[2]) # violinplot for Cn0DbHz
# Out:
# /var/folders/w8/d9x92py92j792gw_1kyfc8sh0000gn/T/ipykernel_21256/2362317376.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(cn0dbhz_eda_uni, kde = True, color = "g", ax = axes[1]) # distplot for Cn0DbHz
# <Axes: >

# %%
# scatterplot for Cn0DbHz vs ErrorYEcefMeters

plt.figure(figsize=(10, 10))
sb.regplot(x="Cn0DbHz", y="ErrorYEcefMeters", data=cn0dbhz_merge_df, scatter_kws={'alpha':0.3, 's':5})
plt.xlabel("Cn0DbHz")
plt.ylabel("ErrorYEcefMeters")
plt.title("Cn0DbHz vs ErrorYEcefMeters")
plt.show()

# %%
# scatterplot for Cn0DbHz vs ErrorYEcefMeters

plt.figure(figsize=(10, 10))
sb.regplot(x="Cn0DbHz", y="ErrorXEcefMeters", color='r', data=cn0dbhz_merge_df, scatter_kws={'alpha':0.3, 's':5})
plt.xlabel("Cn0DbHz")
plt.ylabel("ErrorXEcefMeters")
plt.title("Cn0DbHz vs ErrorXEcefMeters")
plt.show()

# %% [raw]
# # exploratory data analysis - multipathindicator
#     # large proportion of direct signals
#     # wider spread when multipath is 0 must consider larger proportion of signal 0
#     # multipath 1 higher occurrence of positive errors
#     # class imbalance is too great dropping multipathindicator as input feature

# %%
# %store -r multipath_merge_df

plt.figure(figsize=(6,4))
sb.countplot(x="MultipathIndicator", data=multipath_merge_df)
plt.show()

# %%
plt.figure(figsize=(8,6))
sb.boxplot(x="MultipathIndicator", y="ErrorXEcefMeters", data=multipath_merge_df, palette='Set1')
plt.title("MultipathIndicator vs ErrorXEcefMeters")
plt.show()

# %%
print(multipath_merge_df['MultipathIndicator'].value_counts())
# Out:
# MultipathIndicator
# 0    153630
# 1         1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))
sb.boxplot(x="MultipathIndicator", y="ErrorYEcefMeters", data=multipath_merge_df, palette='Set2')
plt.title("MultipathIndicator vs ErrorYEcefMeters")
plt.show()
print()

# %% [raw]
# # exploratory data analysis - satcount
#     # negatively skewed
#     # large variation with multiple clusters across satcounts
#     # median stabilises more to 0 towards higher satcount less >= 48 reducing average error magnitude

# %%
# %store -r satcount_merge_df

f, axes = plt.subplots(1, 3, figsize=(40,20))

# uni-variate visualisation for SatCount eda

satcount_eda_uni = pd.DataFrame(satcount_merge_df[["SatCount"]])
sb.boxplot(satcount_eda_uni, orient = "h", color = "g", ax = axes[0]) # boxplot for SatCount
sb.distplot(satcount_eda_uni, kde = True, color = "g", ax = axes[1]) # distplot for SatCount
sb.violinplot(satcount_eda_uni, orient = "h", color = "g", ax = axes[2]) # violinplot for SatCount
# Out:
# /var/folders/w8/d9x92py92j792gw_1kyfc8sh0000gn/T/ipykernel_21256/1972172772.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(satcount_eda_uni, kde = True, color = "g", ax = axes[1]) # distplot for SatCount
# <Axes: >

# %%
# scatterplot for SatCount vs ErrorXEcefMeters

plt.figure(figsize=(12,6))
sb.countplot(x="SatCount", data=satcount_merge_df)
plt.xticks(rotation=90)
plt.title("SatCount")
plt.show()

# %%
plt.figure(figsize=(8,6))
sb.boxplot(x="SatCount", y="ErrorXEcefMeters", data=satcount_merge_df)
plt.title("SatCount vs ErrorXEcefMeters")
plt.xticks(rotation=90)
plt.show()
print()

# %% [raw]
# # exploratory data analysis - svelevationdegrees
#     # distribution is gaussian with slight negative skew
#     # slight positive correlation between svelevationdegrees vs errorx
#     # slight negative correlation between svelevationdegrees vs errory

# %%
# %store -r elevationdeg_merge_df

f, axes = plt.subplots(1, 3, figsize=(40,20))

# uni-variate visualisation for SvElevationDegrees eda

elevationdeg_eda_uni = pd.DataFrame(elevationdeg_merge_df[["SvElevationDegrees"]])
sb.boxplot(elevationdeg_eda_uni, orient = "h", color = "g", ax = axes[0]) # boxplot for SatCount
sb.distplot(elevationdeg_eda_uni, kde = True, color = "g", ax = axes[1]) # distplot for SatCount
sb.violinplot(elevationdeg_eda_uni, orient = "h", color = "g", ax = axes[2]) # violinplot for SatCount
# Out:
# /var/folders/w8/d9x92py92j792gw_1kyfc8sh0000gn/T/ipykernel_21256/1081946786.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(elevationdeg_eda_uni, kde = True, color = "g", ax = axes[1]) # distplot for SatCount
# <Axes: >

# %%
# scatterplot for Cn0DbHz vs ErrorYEcefMeters

plt.figure(figsize=(10, 10))
sb.regplot(x="SvElevationDegrees", y="ErrorXEcefMeters", data=elevationdeg_merge_df, scatter_kws={'alpha':0.3, 's':5})
plt.xlabel("SvElevationDegrees")
plt.ylabel("ErrorXEcefMeters")
plt.title("SvElevationDegrees vs ErrorXEcefMeters")
plt.show()

# %%
# scatterplot for Cn0DbHz vs ErrorYEcefMeters

plt.figure(figsize=(10, 10))
sb.regplot(x="SvElevationDegrees", y="ErrorYEcefMeters", color='r', data=elevationdeg_merge_df, scatter_kws={'alpha':0.3, 's':5})
plt.xlabel("SvElevationDegrees")
plt.ylabel("ErrorYEcefMeters")
plt.title("SvElevationDegrees vs ErrorYEcefMeters")
plt.show()

# %% [raw]
# # exploratory data analysis - accmag
#     # high proportion of outliers due to compressed box plot we do not remove them because most are in valid range of 5 to 25
#     # distribution is gaussian with positive skew data points cluster tightly about the median
#     # similar scatter plots and reg line slight positive correlation most points centred about the median

# %%
# %store -r accmag_merge_df

f, axes = plt.subplots(3, 1, figsize=(20,40))

# uni-variate visualisation for SvElevationDegrees eda

accmag_eda_uni = pd.DataFrame(accmag_merge_df[["AccMag"]])
sb.boxplot(accmag_eda_uni, orient = "h", color = "g", ax = axes[0]) # boxplot for SatCount
sb.distplot(accmag_eda_uni, kde = True, color = "g", ax = axes[1]) # distplot for SatCount
sb.violinplot(accmag_eda_uni, orient = "h", color = "g", ax = axes[2]) # violinplot for SatCount
# Out:
# /var/folders/w8/d9x92py92j792gw_1kyfc8sh0000gn/T/ipykernel_21256/2240312542.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(accmag_eda_uni, kde = True, color = "g", ax = axes[1]) # distplot for SatCount
# <Axes: >

# %%
# scatterplot for AccMag vs ErrorYEcefMeters

plt.figure(figsize=(10, 10))
sb.regplot(x="AccMag", y="ErrorXEcefMeters", data=accmag_merge_df, scatter_kws={'alpha':0.3, 's':5})
plt.xlabel("AccMag")
plt.ylabel("ErrorXEcefMeters")
plt.title("AccMag vs ErrorXEcefMeters")
plt.show()

# %%
# scatterplot for AccMag vs ErrorYEcefMeters

plt.figure(figsize=(10, 10))
sb.regplot(x="AccMag", y="ErrorYEcefMeters", color='r', data=accmag_merge_df, scatter_kws={'alpha':0.3, 's':5})
plt.xlabel("AccMag")
plt.ylabel("ErrorYEcefMeters")
plt.title("AccMag vs ErrorYEcefMeters")
plt.show()

# %% [raw]
# # exploratory data analysis - gyromag
#     # large positive skew with large proportion of positive outliers
#     # most points are still generally centred about median
#     # high proportion of outliers due to compressed box plot we do not remove them because most are in valid range of 0 to 5
#     # negative correlation for gyromag against both errorx and errory but not strong due to tight clusters

# %%
# %store -r gyromag_merge_df

f, axes = plt.subplots(3, 1, figsize=(20,40))

# uni-variate visualisation for SvElevationDegrees eda

gyromag_eda_uni = pd.DataFrame(gyromag_merge_df[["GyroMag"]])
sb.boxplot(gyromag_eda_uni, orient = "h", color = "g", ax = axes[0]) # boxplot for SatCount
sb.distplot(gyromag_eda_uni, kde = True, color = "g", ax = axes[1]) # distplot for SatCount
sb.violinplot(gyromag_eda_uni, orient = "h", color = "g", ax = axes[2]) # violinplot for SatCount
# Out:
# /var/folders/w8/d9x92py92j792gw_1kyfc8sh0000gn/T/ipykernel_21256/1157098087.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(gyromag_eda_uni, kde = True, color = "g", ax = axes[1]) # distplot for SatCount
# <Axes: >

# %%
# scatterplot for GyroMag vs ErrorXEcefMeters

plt.figure(figsize=(10, 10))
sb.regplot(x="GyroMag", y="ErrorXEcefMeters", data=gyromag_merge_df, scatter_kws={'alpha':0.3, 's':5})
plt.xlabel("GyroMag")
plt.ylabel("ErrorXEcefMeters")
plt.title("GyroMag vs ErrorXEcefMeters")
plt.show()

# %%
# scatterplot for GyroMag vs ErrorYEcefMeters

plt.figure(figsize=(10, 10))
sb.regplot(x="GyroMag", y="ErrorYEcefMeters", color='r', data=gyromag_merge_df, scatter_kws={'alpha':0.3, 's':5})
plt.xlabel("GyroMag")
plt.ylabel("ErrorYEcefMeters")
plt.title("GyroMag vs ErrorYEcefMeters")
plt.show()

# %%
feature = ['GyroMag']
target = ['ErrorYEcefMeters']

corr_matrix = gyromag_merge_df[feature + target].corr()

print(corr_matrix)
# Out:
#                    GyroMag  ErrorYEcefMeters
# GyroMag           1.000000         -0.013669
# ErrorYEcefMeters -0.013669          1.000000

# %%
del multipath_merge_df # class imbalance
